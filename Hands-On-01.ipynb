# %% [markdown]
# Iniciamos o código definindo as bibliotecas necessárias para o projeto

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Usando o **using namespace**, agrupamos todas as declarações relacionadas ao projeto em um escopo fora do global

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Habilita as mensagens de logging.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# No bloco de comandos abaixo, definimos a função inicial do código em C++. Atentando ao comando **Parse**, o qual permite a alteração de parâmetros via terminal sem precisar acessar o arquivo.
# Em seguida, temos o **LogComponentEnable** que habilita os componentes de registro que são construídos com as
# aplicações de **Echo Client e Echo Server**, assim como define o nível informações dos log's.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Agora, começamos de forma mais efetiva a o Hands-On-01.
# Criamos primeiro o **NodeContainer** para facilitar o a criação e gerenciamento dos nós subsequentes.
# Na linha seguinte, é chamado o método **create** e definido o número de nós que desejamos na rede.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Aqui, utilizamos o assistente de topologia, o **PointToPointHelper**. Essa artifício é usado para facilitar configuração do nível mais baixo da rede, por exemplo, as características do canal e dispositivos de redes (placa), dos objetos.
# Em seguida, os objetos **pointToPoint.SetDeviceAttribute e pointToPoint.SetChannelAttribute** são instaciados com a taxa de transmissão e o atraso do canal.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
